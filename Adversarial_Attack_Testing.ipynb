# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import csv
import cv2
import tqdm.notebook as tq
from sklearn.utils import shuffle
from keras.optimizers import *
from keras.losses import *
from keras import Sequential, Model
from keras.layers import *
import PIL
import PIL.Image
import keras.backend as K
import pickle
import keras
from keras.models import load_model
import glob
import os
import ntpath
#tf.config.run_functions_eagerly(True)

# %%
data_location  = 'Dataset/carla_dataset/'
model_location = 'Models/'

# %%
class CarSimulatorAdv(tf.keras.Model):

    def __init__(self):
        super(CarSimulatorAdv, self).__init__()
        self.classifier = load_model(model_location+'model.h5')
        with open(model_location+'mean_image_rgb.pickle', 'rb') as f:
            self.mean = pickle.load(f, encoding='latin1')  # dictionary type
        self.objectdetector = cv2.dnn.readNetFromDarknet(model_location+'yolov3-spp.cfg', model_location+'yolov3-spp.weights')
        self.objectdetector.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
        self.objectdetector.setPreferableTarget(cv2.dnn.DNN_TARGET_OPENCL_FP16)
        self.layers_all = self.objectdetector.getLayerNames()
        self.layers_names_output = [self.layers_all[i[0] - 1] for i in self.objectdetector.getUnconnectedOutLayers()]
        self.probability_minimum = 0.2
        self.threshold = 0.2

    def call(self, input_image, training=False):
        image_BGR = cv2.imread(input_image)
        h, w = image_BGR.shape[:2]

        blob = cv2.dnn.blobFromImage(image_BGR, 1 / 255.0, (416, 416), swapRB=True, crop=False)
        self.objectdetector.setInput(blob)
        output_from_network = self.objectdetector.forward(self.layers_names_output)

        bounding_boxes = []
        confidences = []

        for result in output_from_network:
            for detected_objects in result:
                scores = detected_objects[5:]
                class_current = np.argmax(scores)
                confidence_current = scores[class_current]

                if confidence_current > self.probability_minimum:
                    box_current = detected_objects[0:4] * np.array([w, h, w, h])
                    x_center, y_center, box_width, box_height = box_current
                    x_min = int(x_center - (box_width / 2))
                    y_min = int(y_center - (box_height / 2))
                    bounding_boxes.append([x_min, y_min, int(box_width), int(box_height)])
                    confidences.append(float(confidence_current))

        results = cv2.dnn.NMSBoxes(bounding_boxes, confidences, self.probability_minimum, self.threshold)

        detected_sign = []
        if len(results) > 0:
            for i in results.flatten():
                x_min, y_min = bounding_boxes[i][0], bounding_boxes[i][1]
                box_width, box_height = bounding_boxes[i][2], bounding_boxes[i][3]
                c_ts = image_BGR[y_min:y_min+int(box_height), x_min:x_min+int(box_width), :]
                if c_ts.shape[:1] == (0,) or c_ts.shape[1:2] == (0,):
                    pass
                else:
                    blob_ts = cv2.dnn.blobFromImage(c_ts, 1 / 255.0, size=(32, 32), swapRB=True, crop=False)
                    blob_ts[0] = blob_ts[0, :, :, :] - self.mean['mean_image_rgb']
                    blob_ts = blob_ts.transpose(0, 2, 3, 1)

                    if input_image[-4:] == '.png':
                        input_image = input_image.replace('.png', '.jpg')
                    tf.keras.preprocessing.image.save_img(input_image.replace('.jpg', '_detect.png'), blob_ts[0], scale=True)
                    bolb_img = tf.keras.preprocessing.image.load_img(input_image.replace('.jpg', '_detect.png'), grayscale=False, color_mode='rgb', target_size=(30, 30, 3), interpolation='nearest')
                    bolb_ts = keras.preprocessing.image.img_to_array(bolb_img)
                    X_test = np.array([bolb_ts])
                    scores = np.argmax(self.classifier.predict(X_test), axis=-1)
                    #print(self.classifier.predict(X_test))
                    if scores[0] in range(3):
                        box_info = (x_min, y_min, x_min+box_width, y_min+box_height)
                        detected_sign.append((X_test, scores[0], box_info))
                        break
        return detected_sign

# %%
def image_mapper_adv(input_image, sign, box_info):
    image_path = ntpath.basename(input_image)
    image_b = tf.keras.preprocessing.image.load_img(input_image, grayscale=False, color_mode='rgb', interpolation='nearest')
    imagebg = keras.preprocessing.image.img_to_array(image_b)
    imagebg = np.array(imagebg)

    x1, y1, x2, y2 = box_info
    noisy = tf.keras.preprocessing.image.load_img(sign, grayscale=False, color_mode='rgb', target_size=(y2-y1, x2-x1), interpolation='nearest')
    X_noisy = keras.preprocessing.image.img_to_array(noisy)
    X_noisy = np.array(X_noisy)

    imagebg[y1:y2, x1:x2] = X_noisy

    tf.keras.preprocessing.image.save_img(input_image.replace(image_path, 'AdvImages/'+image_path.replace('.jpg', '_noisy.png')), imagebg, scale=True)

# %%
with open(data_location + 'carla_dataset_annotation.csv', 'r') as f:
    lines = f.read().splitlines()
    scores = {}
    for l in lines:
        x = l.split(',')
        scores[x[0]] = x[1]

# %%
modelAdv = CarSimulatorAdv()
generator = load_model('saved_model2/gen_final.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
def generate_adv():
    count = 0
    img_count = 0
    index = []
    detect_count = 0
    for image in glob.glob(os.path.join(data_location, '*.jpg')):
        #print(img_count)
        try:
            detect = modelAdv(image)
            if len(detect)>0:
                detect_count+=1
                image_path = ntpath.basename(image)
                if int(scores[image_path]) == detect[-1][1]:
                    sign_img = normalization_layer(detect[-1][0])
                    noisy = generator(sign_img)
                    noisy_path = data_location + 'NoisySigns/'+image_path.replace('.jpg', '_noisysign.png')
                    tf.keras.preprocessing.image.save_img(noisy_path, noisy[0], scale=True)
                    image_mapper_adv(image, noisy_path, detect[-1][2])
                    adv_detect = modelAdv(data_location +'AdvImages/'+image_path.replace('.jpg','_noisy.png'))
                    if len(adv_detect)>0:
                        print(image_path, detect[-1][1], adv_detect[-1][1])
                        if int(scores[image_path]) != adv_detect[-1][1]:
                            count+=1
                            index.append(image_path)
                # if img_count == 40:
                #     break
        except:
            continue
        img_count+=1
    print(detect_count)
    return count, index

# %%
count = generate_adv()
# Out:
# DATASET_0001002.jpg 0 0
# DATASET_0001005.jpg 0 0
# DATASET_0001011.jpg 0 2
# DATASET_0001017.jpg 0 2
# DATASET_000102.jpg 1 1
# DATASET_0001021.jpg 0 2
# DATASET_0001023.jpg 0 2
# DATASET_0001027.jpg 0 2
# DATASET_0001033.jpg 0 2
# DATASET_0001037.jpg 0 2
# DATASET_0001039.jpg 0 2
# DATASET_0001041.jpg 0 2
# DATASET_0001043.jpg 0 2
# DATASET_0001045.jpg 0 2
# DATASET_0001046.jpg 0 0
# DATASET_0001049.jpg 0 2
# DATASET_0001055.jpg 1 2
# DATASET_000106.jpg 1 1
# DATASET_0001068.jpg 0 0
# DATASET_0001069.jpg 0 0
# DATASET_0001071.jpg 1 1
# DATASET_0001073.jpg 1 1
# DATASET_0001075.jpg 1 1
# DATASET_0001077.jpg 1 1
# DATASET_0001079.jpg 1 2
# DATASET_000108.jpg 1 1
# DATASET_0001088.jpg 0 0
# DATASET_0001089.jpg 0 0
# DATASET_0001102.jpg 0 0
# DATASET_000115.jpg 1 2
# DATASET_0001151.jpg 0 2
# DATASET_0001187.jpg 0 2
# DATASET_0001199.jpg 0 0
# DATASET_0001223.jpg 0 2
# DATASET_000124.jpg 2 2
# DATASET_0001248.jpg 0 2
# DATASET_0001268.jpg 0 2
# DATASET_0001270.jpg 0 2
# DATASET_0001272.jpg 0 0
# DATASET_0001276.jpg 0 0
# DATASET_0001280.jpg 0 0
# DATASET_0001284.jpg 0 0
# DATASET_0001288.jpg 0 0
# DATASET_0001294.jpg 0 2
# DATASET_0001296.jpg 0 2
# DATASET_000130.jpg 2 2
# DATASET_0001300.jpg 0 0
# DATASET_0001301.jpg 1 2
# DATASET_0001302.jpg 0 0
# DATASET_0001310.jpg 1 2
# DATASET_0001319.jpg 2 2
# DATASET_000132.jpg 2 2
# DATASET_000148.jpg 0 0
# DATASET_00015.jpg 2 2
# DATASET_000154.jpg 0 0
# DATASET_000158.jpg 1 2
# DATASET_000159.jpg 1 1
# DATASET_00016.jpg 1 2
# DATASET_000166.jpg 0 0
# DATASET_000168.jpg 0 2
# DATASET_00017.jpg 2 2
# DATASET_000170.jpg 0 0
# DATASET_000172.jpg 0 0
# DATASET_000174.jpg 0 0
# DATASET_000176.jpg 1 1
# DATASET_000178.jpg 0 0
# DATASET_00018.jpg 1 2
# DATASET_000181.jpg 1 2
# DATASET_000182.jpg 0 0
# DATASET_000184.jpg 0 2
# DATASET_000188.jpg 0 0
# DATASET_00019.jpg 2 2
# DATASET_000194.jpg 0 0
# DATASET_000196.jpg 0 2
# DATASET_000198.jpg 0 0
# DATASET_0002.jpg 1 1
# DATASET_00020.jpg 1 2
# DATASET_000204.jpg 0 2
# DATASET_000206.jpg 0 2
# DATASET_000208.jpg 0 2
# DATASET_00021.jpg 2 2
# DATASET_000210.jpg 0 2
# DATASET_000214.jpg 0 2
# DATASET_000216.jpg 0 0
# DATASET_00022.jpg 1 2
# DATASET_000220.jpg 0 0
# DATASET_000222.jpg 0 0
# DATASET_000227.jpg 1 1
# DATASET_00023.jpg 2 2
# DATASET_000232.jpg 0 2
# DATASET_000244.jpg 0 2
# DATASET_00025.jpg 2 2
# DATASET_000250.jpg 0 2
# DATASET_00026.jpg 1 2
# DATASET_000260.jpg 1 2
# DATASET_000264.jpg 1 2
# DATASET_00027.jpg 1 2
# DATASET_000271.jpg 1 1
# DATASET_000280.jpg 1 2
# DATASET_000282.jpg 1 2
# DATASET_000288.jpg 1 2
# DATASET_000293.jpg 1 2
# DATASET_000308.jpg 0 0
# DATASET_00031.jpg 2 2
# DATASET_000320.jpg 1 1
# DATASET_000324.jpg 1 2
# DATASET_000332.jpg 1 1
# DATASET_00034.jpg 1 1
# DATASET_000342.jpg 2 2
# DATASET_0003435.jpg 0 2
# DATASET_000344.jpg 2 2
# DATASET_0003490.jpg 0 0
# DATASET_0003512.jpg 0 0
# DATASET_0003523.jpg 0 0
# DATASET_0003534.jpg 0 0
# DATASET_000354.jpg 1 2
# DATASET_0003547.jpg 0 0
# DATASET_0003558.jpg 0 0
# DATASET_0003569.jpg 0 0
# DATASET_000358.jpg 2 2
# DATASET_000359.jpg 1 1
# DATASET_00036.jpg 1 2
# DATASET_0003613.jpg 0 0
# DATASET_0003624.jpg 0 0
# DATASET_000364.jpg 0 2
# DATASET_000366.jpg 0 2
# DATASET_000374.jpg 0 0
# DATASET_000378.jpg 0 2
# DATASET_00038.jpg 1 2
# DATASET_000380.jpg 2 2
# DATASET_000381.jpg 1 1
# DATASET_000384.jpg 0 2
# DATASET_000388.jpg 0 2
# DATASET_000392.jpg 0 0
# DATASET_000398.jpg 0 2
# DATASET_00040.jpg 1 2
# DATASET_000402.jpg 2 2
# DATASET_000403.jpg 1 2
# DATASET_000408.jpg 0 0
# DATASET_000410.jpg 0 0
# DATASET_000412.jpg 0 2
# DATASET_000414.jpg 1 2
# DATASET_000418.jpg 1 1
# DATASET_000422.jpg 1 2
# DATASET_00043.jpg 0 2
# DATASET_000430.jpg 0 2
# DATASET_000434.jpg 0 0
# DATASET_000436.jpg 0 2
# DATASET_00044.jpg 1 2
# DATASET_000440.jpg 1 2
# DATASET_000442.jpg 1 0
# DATASET_000444.jpg 1 2
# DATASET_000446.jpg 0 0
# DATASET_000449.jpg 0 0
# DATASET_000452.jpg 1 2
# DATASET_000454.jpg 1 1
# DATASET_000456.jpg 1 0
# DATASET_000458.jpg 1 2
# DATASET_00046.jpg 1 2
# DATASET_000460.jpg 1 2
# DATASET_000462.jpg 1 2
# DATASET_000464.jpg 1 1
# DATASET_000466.jpg 1 2
# DATASET_000468.jpg 1 2
# DATASET_000472.jpg 1 1
# DATASET_000476.jpg 1 1
# DATASET_000488.jpg 1 1
# DATASET_00049.jpg 1 1
# DATASET_000494.jpg 0 0
# DATASET_000496.jpg 0 0
# DATASET_0005.jpg 1 2
# DATASET_00050.jpg 1 2
# DATASET_000500.jpg 0 2
# DATASET_000514.jpg 1 2
# DATASET_000534.jpg 1 2
# DATASET_000540.jpg 1 2
# DATASET_000544.jpg 1 2
# DATASET_000548.jpg 1 1
# DATASET_000552.jpg 1 1
# DATASET_000554.jpg 1 1
# DATASET_000560.jpg 1 1
# DATASET_000562.jpg 1 2
# DATASET_000566.jpg 1 2
# DATASET_000572.jpg 1 1
# DATASET_00058.jpg 1 2
# DATASET_000581.jpg 1 1
# DATASET_000582.jpg 1 2
# DATASET_000584.jpg 1 2
# DATASET_000588.jpg 1 1
# DATASET_0005881.jpg 2 2
# DATASET_0005883.jpg 2 2
# DATASET_0005885.jpg 2 2
# DATASET_0005886.jpg 2 2
# DATASET_0005887.jpg 2 2
# DATASET_0005889.jpg 2 2
# DATASET_0005890.jpg 2 2
# DATASET_0005891.jpg 2 2
# DATASET_0005893.jpg 2 2
# DATASET_0005894.jpg 2 2
# DATASET_0005897.jpg 2 2
# DATASET_0005899.jpg 2 2
# DATASET_00059.jpg 0 2
# DATASET_0005901.jpg 2 2
# DATASET_0005906.jpg 2 2
# DATASET_0005910.jpg 2 2
# DATASET_0005912.jpg 2 2
# DATASET_0005914.jpg 2 2
# DATASET_0005915.jpg 2 2
# DATASET_0005916.jpg 2 2
# DATASET_0005917.jpg 2 2
# DATASET_000603.jpg 1 2
# DATASET_0006079.jpg 0 0
# DATASET_0006080.jpg 0 2
# DATASET_000624.jpg 0 2
# DATASET_0006367.jpg 0 0
# DATASET_0006372.jpg 0 2
# DATASET_0006373.jpg 0 1
# DATASET_0006374.jpg 0 0
# DATASET_0006376.jpg 0 2
# DATASET_0006378.jpg 0 1
# DATASET_0006383.jpg 0 0
# DATASET_0006384.jpg 0 0
# DATASET_0006385.jpg 0 2
# DATASET_0006388.jpg 0 0
# DATASET_0006389.jpg 0 0
# DATASET_00064.jpg 1 2
# DATASET_000669.jpg 0 2
# DATASET_00070.jpg 1 2
# DATASET_00071.jpg 1 2
# DATASET_00072.jpg 0 2
# DATASET_000758.jpg 0 2
# DATASET_0007714.jpg 0 2
# DATASET_0007716.jpg 0 2
# DATASET_0007729.jpg 0 0
# DATASET_0007731.jpg 0 0
# DATASET_0007732.jpg 0 0
# DATASET_0007734.jpg 0 2
# DATASET_0007736.jpg 0 0
# DATASET_0007738.jpg 0 2
# DATASET_0007739.jpg 0 0
# DATASET_0008.jpg 1 2
# DATASET_00080.jpg 1 2
# DATASET_0008003.jpg 1 2
# DATASET_0008004.jpg 1 2
# DATASET_0008006.jpg 1 2
# DATASET_0008009.jpg 1 2
# DATASET_0008010.jpg 1 2
# DATASET_0008011.jpg 1 1
# DATASET_0008012.jpg 1 1
# DATASET_0008013.jpg 1 1
# DATASET_0008015.jpg 1 2
# DATASET_0008016.jpg 1 1
# DATASET_0008017.jpg 1 2
# DATASET_0008018.jpg 1 2
# DATASET_000802.jpg 0 2
# DATASET_0008024.jpg 1 2
# DATASET_000805.jpg 2 2
# DATASET_0008114.jpg 0 2
# DATASET_0008117.jpg 0 0
# DATASET_0008120.jpg 0 2
# DATASET_0008122.jpg 0 2
# DATASET_0008123.jpg 0 2
# DATASET_0008124.jpg 0 0
# DATASET_000824.jpg 0 0
# DATASET_000825.jpg 1 1
# DATASET_000846.jpg 0 0
# DATASET_000847.jpg 2 2
# DATASET_0008559.jpg 2 2
# DATASET_0008560.jpg 2 2
# DATASET_0008569.jpg 2 2
# DATASET_0008571.jpg 2 2
# DATASET_0008572.jpg 2 2
# DATASET_0008573.jpg 2 2
# DATASET_0008576.jpg 2 2
# DATASET_0008577.jpg 2 2
# DATASET_0008578.jpg 2 2
# DATASET_0008579.jpg 2 2
# DATASET_0008581.jpg 2 2
# DATASET_0008583.jpg 2 2
# DATASET_0008590.jpg 2 2
# DATASET_0008591.jpg 2 2
# DATASET_00086.jpg 0 2
# DATASET_000868.jpg 0 2
# DATASET_000869.jpg 2 2
# DATASET_0008716.jpg 0 2
# DATASET_0008772.jpg 1 2
# DATASET_0008773.jpg 1 2
# DATASET_0008775.jpg 1 2
# DATASET_0008776.jpg 1 2
# DATASET_0008777.jpg 1 2
# DATASET_0008778.jpg 1 2
# DATASET_0008782.jpg 1 2
# DATASET_0008787.jpg 1 2
# DATASET_0008810.jpg 0 2
# DATASET_000887.jpg 2 2
# DATASET_000889.jpg 2 2
# DATASET_0008905.jpg 2 2
# DATASET_0008910.jpg 2 2
# DATASET_0008913.jpg 2 2
# DATASET_0008914.jpg 2 2
# DATASET_0008915.jpg 2 2
# DATASET_0008918.jpg 2 2
# DATASET_000892.jpg 0 0
# DATASET_000893.jpg 2 2
# DATASET_000895.jpg 2 2
# DATASET_000897.jpg 2 2
# DATASET_000899.jpg 2 2
# DATASET_0008994.jpg 0 2
# DATASET_0009.jpg 2 2
# DATASET_00090.jpg 1 2
# DATASET_00091.jpg 0 2
# DATASET_000914.jpg 0 0
# DATASET_0009149.jpg 2 2
# DATASET_0009150.jpg 2 2
# DATASET_0009151.jpg 2 2
# DATASET_0009153.jpg 2 2
# DATASET_0009154.jpg 2 2
# DATASET_0009155.jpg 2 2
# DATASET_0009156.jpg 2 2
# DATASET_0009157.jpg 2 2
# DATASET_0009158.jpg 2 2
# DATASET_0009159.jpg 2 2
# DATASET_0009160.jpg 2 2
# DATASET_0009161.jpg 2 2
# DATASET_0009162.jpg 2 2
# DATASET_0009164.jpg 2 2
# DATASET_0009165.jpg 2 2
# DATASET_0009166.jpg 2 2
# DATASET_0009167.jpg 2 2
# DATASET_0009168.jpg 2 2
# DATASET_0009169.jpg 2 2
# DATASET_0009170.jpg 2 2
# DATASET_0009171.jpg 2 2
# DATASET_0009172.jpg 2 2
# DATASET_0009289.jpg 1 1
# DATASET_0009294.jpg 0 0
# DATASET_0009295.jpg 0 2
# DATASET_0009297.jpg 0 0
# DATASET_0009299.jpg 0 0
# DATASET_00093.jpg 1 1
# DATASET_0009300.jpg 0 2
# DATASET_0009359.jpg 0 2
# DATASET_000936.jpg 0 2
# DATASET_0009378.jpg 0 2
# DATASET_0009379.jpg 0 0
# DATASET_0009380.jpg 0 0
# DATASET_0009382.jpg 0 0
# DATASET_0009383.jpg 0 0
# DATASET_0009384.jpg 0 2
# DATASET_0009386.jpg 0 0
# DATASET_0009387.jpg 0 0
# DATASET_0009388.jpg 0 0
# DATASET_0009389.jpg 0 2
# DATASET_0009391.jpg 0 2
# DATASET_0009392.jpg 0 0
# DATASET_0009393.jpg 0 0
# DATASET_0009394.jpg 0 0
# DATASET_0009402.jpg 0 2
# DATASET_000949.jpg 0 2
# DATASET_000955.jpg 0 2
# DATASET_000958.jpg 0 0
# DATASET_00096.jpg 1 1
# DATASET_000965.jpg 0 0
# DATASET_000967.jpg 0 0
# DATASET_000969.jpg 0 0
# DATASET_000973.jpg 0 2
# DATASET_000979.jpg 0 0
# DATASET_000980.jpg 0 0
# 861

# %%
count[0], count[1]
# Out:
# (155,
#  ['DATASET_0001011.jpg',
#   'DATASET_0001017.jpg',
#   'DATASET_0001021.jpg',
#   'DATASET_0001023.jpg',
#   'DATASET_0001027.jpg',
#   'DATASET_0001033.jpg',
#   'DATASET_0001037.jpg',
#   'DATASET_0001039.jpg',
#   'DATASET_0001041.jpg',
#   'DATASET_0001043.jpg',
#   'DATASET_0001045.jpg',
#   'DATASET_0001049.jpg',
#   'DATASET_0001055.jpg',
#   'DATASET_0001079.jpg',
#   'DATASET_000115.jpg',
#   'DATASET_0001151.jpg',
#   'DATASET_0001187.jpg',
#   'DATASET_0001223.jpg',
#   'DATASET_0001248.jpg',
#   'DATASET_0001268.jpg',
#   'DATASET_0001270.jpg',
#   'DATASET_0001294.jpg',
#   'DATASET_0001296.jpg',
#   'DATASET_0001301.jpg',
#   'DATASET_0001310.jpg',
#   'DATASET_000158.jpg',
#   'DATASET_00016.jpg',
#   'DATASET_000168.jpg',
#   'DATASET_00018.jpg',
#   'DATASET_000181.jpg',
#   'DATASET_000184.jpg',
#   'DATASET_000196.jpg',
#   'DATASET_00020.jpg',
#   'DATASET_000204.jpg',
#   'DATASET_000206.jpg',
#   'DATASET_000208.jpg',
#   'DATASET_000210.jpg',
#   'DATASET_000214.jpg',
#   'DATASET_00022.jpg',
#   'DATASET_000232.jpg',
#   'DATASET_000244.jpg',
#   'DATASET_000250.jpg',
#   'DATASET_00026.jpg',
#   'DATASET_000260.jpg',
#   'DATASET_000264.jpg',
#   'DATASET_00027.jpg',
#   'DATASET_000280.jpg',
#   'DATASET_000282.jpg',
#   'DATASET_000288.jpg',
#   'DATASET_000293.jpg',
#   'DATASET_000324.jpg',
#   'DATASET_0003435.jpg',
#   'DATASET_000354.jpg',
#   'DATASET_00036.jpg',
#   'DATASET_000364.jpg',
#   'DATASET_000366.jpg',
#   'DATASET_000378.jpg',
#   'DATASET_00038.jpg',
#   'DATASET_000384.jpg',
#   'DATASET_000388.jpg',
#   'DATASET_000398.jpg',
#   'DATASET_00040.jpg',
#   'DATASET_000403.jpg',
#   'DATASET_000412.jpg',
#   'DATASET_000414.jpg',
#   'DATASET_000422.jpg',
#   'DATASET_00043.jpg',
#   'DATASET_000430.jpg',
#   'DATASET_000436.jpg',
#   'DATASET_00044.jpg',
#   'DATASET_000440.jpg',
#   'DATASET_000442.jpg',
#   'DATASET_000444.jpg',
#   'DATASET_000452.jpg',
#   'DATASET_000456.jpg',
#   'DATASET_000458.jpg',
#   'DATASET_00046.jpg',
#   'DATASET_000460.jpg',
#   'DATASET_000462.jpg',
#   'DATASET_000466.jpg',
#   'DATASET_000468.jpg',
#   'DATASET_0005.jpg',
#   'DATASET_00050.jpg',
#   'DATASET_000500.jpg',
#   'DATASET_000514.jpg',
#   'DATASET_000534.jpg',
#   'DATASET_000540.jpg',
#   'DATASET_000544.jpg',
#   'DATASET_000562.jpg',
#   'DATASET_000566.jpg',
#   'DATASET_00058.jpg',
#   'DATASET_000582.jpg',
#   'DATASET_000584.jpg',
#   'DATASET_00059.jpg',
#   'DATASET_000603.jpg',
#   'DATASET_0006080.jpg',
#   'DATASET_000624.jpg',
#   'DATASET_0006372.jpg',
#   'DATASET_0006373.jpg',
#   'DATASET_0006376.jpg',
#   'DATASET_0006378.jpg',
#   'DATASET_0006385.jpg',
#   'DATASET_00064.jpg',
#   'DATASET_000669.jpg',
#   'DATASET_00070.jpg',
#   'DATASET_00071.jpg',
#   'DATASET_00072.jpg',
#   'DATASET_000758.jpg',
#   'DATASET_0007714.jpg',
#   'DATASET_0007716.jpg',
#   'DATASET_0007734.jpg',
#   'DATASET_0007738.jpg',
#   'DATASET_0008.jpg',
#   'DATASET_00080.jpg',
#   'DATASET_0008003.jpg',
#   'DATASET_0008004.jpg',
#   'DATASET_0008006.jpg',
#   'DATASET_0008009.jpg',
#   'DATASET_0008010.jpg',
#   'DATASET_0008015.jpg',
#   'DATASET_0008017.jpg',
#   'DATASET_0008018.jpg',
#   'DATASET_000802.jpg',
#   'DATASET_0008024.jpg',
#   'DATASET_0008114.jpg',
#   'DATASET_0008120.jpg',
#   'DATASET_0008122.jpg',
#   'DATASET_0008123.jpg',
#   'DATASET_00086.jpg',
#   'DATASET_000868.jpg',
#   'DATASET_0008716.jpg',
#   'DATASET_0008772.jpg',
#   'DATASET_0008773.jpg',
#   'DATASET_0008775.jpg',
#   'DATASET_0008776.jpg',
#   'DATASET_0008777.jpg',
#   'DATASET_0008778.jpg',
#   'DATASET_0008782.jpg',
#   'DATASET_0008787.jpg',
#   'DATASET_0008810.jpg',
#   'DATASET_0008994.jpg',
#   'DATASET_00090.jpg',
#   'DATASET_00091.jpg',
#   'DATASET_0009295.jpg',
#   'DATASET_0009300.jpg',
#   'DATASET_0009359.jpg',
#   'DATASET_000936.jpg',
#   'DATASET_0009378.jpg',
#   'DATASET_0009384.jpg',
#   'DATASET_0009389.jpg',
#   'DATASET_0009391.jpg',
#   'DATASET_0009402.jpg',
#   'DATASET_000949.jpg',
#   'DATASET_000955.jpg',
#   'DATASET_000973.jpg'])
